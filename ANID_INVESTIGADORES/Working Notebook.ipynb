# %%
import requests
#42683 max
#10000 min

# %%
url = "https://investigadores.anid.cl/es/public_search/researcher?id=10008"

# %%
ANID = requests.get(url)

# %%
ANID.status_code
# Out:
# 404

# %%
print(ANID.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#   <title>The page you were looking for doesn't exist (404)</title>
#   <style type="text/css">
#     body { background-color: #fff; color: #666; text-align: center; font-family: arial, sans-serif; }
#     div.dialog {
#       width: 25em;
#       padding: 0 4em;
#       margin: 4em auto 0 auto;
#       border: 1px solid #ccc;
#       border-right-color: #999;
#       border-bottom-color: #999;
#     }
#     h1 { font-size: 100%; color: #f00; line-height: 1.5em; }
#   </style>
# </head>
#
# <body>
#   <!-- This file lives in public/404.html -->
#   <div class="dialog">
#     <h1>The page you were looking for doesn't exist.</h1>
#     <p>You may have mistyped the address or the page may have moved.</p>
#   </div>
# </body>
# </html>

# %%
print(ANID.content)
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n  <title>The page you were looking for doesn\'t exist (404)</title>\n  <style type="text/css">\n    body { background-color: #fff; color: #666; text-align: center; font-family: arial, sans-serif; }\n    div.dialog {\n      width: 25em;\n      padding: 0 4em;\n      margin: 4em auto 0 auto;\n      border: 1px solid #ccc;\n      border-right-color: #999;\n      border-bottom-color: #999;\n    }\n    h1 { font-size: 100%; color: #f00; line-height: 1.5em; }\n  </style>\n</head>\n\n<body>\n  <!-- This file lives in public/404.html -->\n  <div class="dialog">\n    <h1>The page you were looking for doesn\'t exist.</h1>\n    <p>You may have mistyped the address or the page may have moved.</p>\n  </div>\n</body>\n</html>\n'

# %%
# Encabezado de la respuesta
print(ANID.headers['Content-length'])
# Out:
# 728

# %%
# Encabezado de la solicitud
ANID.request.headers
# Out:
# {'User-Agent': 'python-requests/2.25.1', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
ANID.request.method
# Out:
# 'GET'

# %%
ANID.request.url
# Out:
# 'https://investigadores.anid.cl/es/public_search/researcher?id=21696'

# %%
from bs4 import BeautifulSoup

# %%
ANID_soup = BeautifulSoup(ANID.text, 'lxml')

# %%
type(ANID_soup)
# Out:
# bs4.BeautifulSoup

# %%
print(ANID_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8"/>
#   <title>
#    PDI - Resultado de Búsqueda
#   </title>
#   <meta content="Drag &amp; drop hierarchical list" name="description"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
#   <!-- bootstrap & fontawesome -->
#   <link href="/stylesheets/external/bootstrap.css" rel="stylesheet"/>
#   <link href="/font/font-awesome-4.5/font-awesome.css" rel="stylesheet"/>
#   <!-- page specific plugin styles -->
#   <!-- text fonts -->
#   <link href="/font/font-awesome-4.5/ace-fonts.css" rel="stylesheet"/>
#   <!-- ace styles -->
#   <link class="ace-main-stylesheet" href="/stylesheets/external/ace.css" id="main-ace-style" rel="stylesheet"/>
#   <!--[if lte IE 9]>
# 			<link rel="stylesheet" href="/stylesheets/external/ace-part2.css" class="ace-main-stylesheet" />
# 		<![endif]-->
#   <!--[if lte IE 9]>
# 		  <link rel="stylesheet" href="/stylesheets/external/ace-ie.css" />
# 		<![endif]-->
#   <!-- inline styles related to this page -->
#   <!-- ace settings handler -->
#   <script src="/javascripts/external/ace-extra.js">
#   </script>
#   <!-- HTML5shiv and Respond.js for IE8 to support HTML5 elements and media queries -->
#   <!--[if lte IE 8]>
# 		<script src="/javascripts/external/html5shiv.js"></script>
# 		<script src="/javascripts/external/respond.js"></script>
# 		<![endif]-->
#  </head>
#  <body class="no-skin">
#   <!-- #section:basics/navbar.layout -->
#   <div class="navbar navbar-default ace-save-state" id="navbar">
#    <div class="navbar-container ace-save-state" id="navbar-container">
#     <!-- /section:basics/sidebar.mobile.toggle -->
#     <div class="navbar-header pull-left">
#      <!-- #section:basics/navbar.layout.brand -->
#      <a class="navbar-brand" href="/es/login">
#       <small>
#        <img alt="Ico" height="25" src="/images/ico.png?1455897068" width="25"/>
#        Portal del Investigador
#       </small>
#      </a>
#      <!-- /section:basics/navbar.layout.brand -->
#      <!-- #section:basics/navbar.toggle -->
#      <!-- /section:basics/navbar.toggle -->
#     </div>
#     <!-- #section:basics/navbar.dropdown -->
#     <div class="navbar-buttons navbar-header pull-right" role="navigation">
#      <ul class="nav ace-nav">
#       <li>
#        <a href="javascript:window.close()">
#         <i class="ace-icon fa fa-times">
#         </i>
#         Cerrar
#        </a>
#       </li>
#      </ul>
#     </div>
#     <!-- /section:basics/navbar.dropdown -->
#    </div>
#    <!-- /.navbar-container -->
#   </div>
#   <!-- /section:basics/navbar.layout -->
#   <div class="main-container ace-save-state" id="main-container" style="max-width:700px;margin-left:auto;margin-right:auto;">
#    <script type="text/javascript">
#     try{ace.settings.loadState('main-container')}catch(e){}
#    </script>
#    <!-- /section:basics/sidebar -->
#    <div class="main-content">
#     <div class="main-content-inner">
#      <!-- /section:basics/content.breadcrumbs -->
#      <div class="page-content">
#       <div class="row">
#        <div class="col-xs-12" style="margin-top:20px;">
#         <!-- PAGE CONTENT BEGINS -->
#         <div class="row">
#          <div class="col-sm-2">
#           <span class="profile-picture">
#            <img alt="Man" class="avatar img-responsive" height="135" src="/images/man.jpg?1635187222"/>
#           </span>
#          </div>
#          <!-- /.col -->
#          <div class="col-sm-6" style="line-height:7px;margin-top:-15px;">
#           <h3>
#            <strong>
#             Elizabeth Patricia Zenteno Torres
#            </strong>
#           </h3>
#           <p style="line-height:12px;">
#            <strong>
#             Profesor Asistente
#            </strong>
#           </p>
#           <p style="line-height:12px;">
#            UNIVERSIDAD DE PLAYA ANCHA DE CIENCIAS DE LA EDUCACION
#           </p>
#           <p>
#            <small>
#            </small>
#           </p>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="row" style="margin-top:30px;margin-left:2px;margin-right:1px;">
#        <div class="tabbable">
#         <ul class="nav nav-tabs" id="myTab">
#          <li class="active">
#           <a aria-expanded="true" data-toggle="tab" href="#home">
#            <i class="default ace-icon fa fa-user bigger-120">
#            </i>
#            Currículo
#           </a>
#          </li>
#          <li>
#           <a aria-expanded="false" data-toggle="tab" href="#messages">
#            <i class="default ace-icon fa fa-file-text bigger-120">
#            </i>
#            Producción (0)
#           </a>
#          </li>
#          <li class="dropdown">
#           <a aria-expanded="false" data-toggle="tab" href="#colab">
#            <i class="default ace-icon fa fa-users bigger-120">
#            </i>
#            Colaboraciones (0)
#           </a>
#          </li>
#         </ul>
#         <div class="tab-content">
#          <div class="tab-pane fade active in" id="home">
#           <div class="widget-header widget-header-small" style="background:none;">
#            <h4 class="widget-title blue smaller">
#             <i class="ace-icon fa fa-bookmark orange">
#             </i>
#             Líneas de Investigación
#            </h4>
#           </div>
#           <br/>
#           <p>
#            Sociología urbana; Pobreza y segregación urbana; Metodología cualitativa
#           </p>
#           <div class="widget-header widget-header-small" style="background:none;margin-top:40px;">
#            <h4 class="widget-title blue smaller">
#             <i class="ace-icon fa fa-graduation-cap orange">
#             </i>
#             Educación
#            </h4>
#           </div>
#           <div>
#            <ul class="list-unstyled">
#             <li class="muted">
#              <h5>
#               <i class="ace-icon fa fa-angle-right bigger-110">
#               </i>
#               <strong>
#                Licenciatura en Sociología
#               </strong>
#               ,
#               <span class="text-warning">
#                UNIVERSIDAD DE PLAYA ANCHA DE CIENCIAS DE LA EDUCACION
#               </span>
#               .
#               <small>
#                Chile, 2008
#               </small>
#              </h5>
#             </li>
#             <li class="muted">
#              <h5>
#               <i class="ace-icon fa fa-angle-right bigger-110">
#               </i>
#               <strong>
#                MASTER CONJUNTO INTERNACIONAL EN POLÍTICAS PÚBLICAS Y DESARROLLO TERRITORIAL: GOBERNABILIDAD Y PROCESOS DE INTEGRACIÓN
#               </strong>
#               ,
#               <span class="text-warning">
#                UNIVERSITA DEGLI STUDI DI PALERMO
#               </span>
#               .
#               <small>
#                Italia, 2010
#               </small>
#              </h5>
#             </li>
#             <li class="muted">
#              <h5>
#               <i class="ace-icon fa fa-angle-right bigger-110">
#               </i>
#               <strong>
#                DOCTORADO EN TEORÍA E INVESTIGACIÓN SOCIAL
#               </strong>
#               ,
#               <span class="text-warning">
#                UNIVERSITA DEGLI STUDI DI ROMA LA SAPIENZA
#               </span>
#               .
#               <small>
#                Italia, 2015
#               </small>
#              </h5>
#             </li>
#             <li class="muted">
#              <h5>
#               <i class="ace-icon fa fa-angle-right bigger-110">
#               </i>
#               <strong>
#                Sociólogo
#               </strong>
#               ,
#               <span class="text-warning">
#                UNIVERSIDAD DE PLAYA ANCHA DE CIENCIAS DE LA EDUCACION
#               </span>
#               .
#               <small>
#                Chile, 2008
#               </small>
#              </h5>
#             </li>
#            </ul>
#           </div>
#           <div class="widget-header widget-header-small" style="background:none;margin-top:40px;">
#            <h4 class="widget-title blue smaller">
#             <i class="ace-icon fa fa-institution orange">
#             </i>
#             Experiencia Académica
#            </h4>
#           </div>
#           <div>
#            <ul class="list-unstyled" style="line-height:10px;">
#             <li class="muted" style="margin-bottom:20px;">
#              <h5>
#               <i class="ace-icon fa fa-angle-right bigger-110">
#               </i>
#               <strong>
#                Profesor Asistente
#               </strong>
#               <small>
#                Part Time
#               </small>
#              </h5>
#              <div style="margin-left:10px;">
#               <p>
#                <span class="text-warning capitalize">
#                 UNIVERSIDAD DE PLAYA ANCHA DE CIENCIAS DE LA EDUCACION
#                </span>
#               </p>
#               <p>
#                Ciencias Sociales
#               </p>
#               <p>
#                <small>
#                 Valparaíso, Chile
#                </small>
#               </p>
#               <p>
#                <small>
#                 <strong>
#                  2015 - A la fecha
#                 </strong>
#                </small>
#               </p>
#              </div>
#             </li>
#            </ul>
#           </div>
#           <div class="widget-header widget-header-small" style="background:none;margin-top:40px;">
#            <h4 class="widget-title blue smaller">
#             <i class="ace-icon fa fa-suitcase orange">
#             </i>
#             Experiencia Profesional
#            </h4>
#           </div>
#           <div>
#            <ul class="list-unstyled" style="line-height:10px;">
#             <li class="muted" style="margin-bottom:20px;">
#              <h5>
#               <i class="ace-icon fa fa-angle-right bigger-110">
#               </i>
#               <strong>
#                Docente del curso Etnografía de la alteridad
#               </strong>
#               <small>
#               </small>
#              </h5>
#              <div style="margin-left:10px;">
#               <p>
#                <span class="text-warning capitalize">
#                 Universidad de Playa Ancha. Departamento de Sociología.
#                </span>
#               </p>
#               <p>
#                <small>
#                 Chile
#                </small>
#               </p>
#               <p>
#                <small>
#                 <strong>
#                  2016 - A la fecha
#                 </strong>
#                </small>
#               </p>
#              </div>
#             </li>
#             <li class="muted" style="margin-bottom:20px;">
#              <h5>
#               <i class="ace-icon fa fa-angle-right bigger-110">
#               </i>
#               <strong>
#                Docente del curso Metodología de la investigación I
#               </strong>
#               <small>
#               </small>
#              </h5>
#              <div style="margin-left:10px;">
#               <p>
#                <span class="text-warning capitalize">
#                 Universidad de Playa Ancha. Departamento de Sociología.
#                </span>
#               </p>
#               <p>
#                <small>
#                 Chile
#                </small>
#               </p>
#               <p>
#                <small>
#                 <strong>
#                  2015 - A la fecha
#                 </strong>
#                </small>
#               </p>
#              </div>
#             </li>
#             <li class="muted" style="margin-bottom:20px;">
#              <h5>
#               <i class="ace-icon fa fa-angle-right bigger-110">
#               </i>
#               <strong>
#                Docente del curso Metodología de la Investigación Cualitativa I
#               </strong>
#               <small>
#               </small>
#              </h5>
#              <div style="margin-left:10px;">
#               <p>
#                <span class="text-warning capitalize">
#                 Universidad de Playa Ancha. Departamento de Sociología.
#                </span>
#               </p>
#               <p>
#                <small>
#                 Chile
#                </small>
#               </p>
#               <p>
#                <small>
#                 <strong>
#                  2015 - A la fecha
#                 </strong>
#                </small>
#               </p>
#              </div>
#             </li>
#             <li class="muted" style="margin-bottom:20px;">
#              <h5>
#               <i class="ace-icon fa fa-angle-right bigger-110">
#               </i>
#               <strong>
#                Docente del curso Sociología General
#               </strong>
#               <small>
#               </small>
#              </h5>
#              <div style="margin-left:10px;">
#               <p>
#                <span class="text-warning capitalize">
#                 Universidad de Playa Ancha. Carrera: Terapia Ocupacional
#                </span>
#               </p>
#               <p>
#                <small>
#                 Chile
#                </small>
#               </p>
#               <p>
#                <small>
#                 <strong>
#                  2016 - A la fecha
#                 </strong>
#                </small>
#               </p>
#              </div>
#             </li>
#             <li class="muted" style="margin-bottom:20px;">
#              <h5>
#               <i class="ace-icon fa fa-angle-right bigger-110">
#               </i>
#               <strong>
#                Docente del curso Población y Desarrollo Sustentable
#               </strong>
#               <small>
#               </small>
#              </h5>
#              <div style="margin-left:10px;">
#               <p>
#                <span class="text-warning capitalize">
#                 Universidad de Playa Ancha. Departamento de Sociología.
#                </span>
#               </p>
#               <p>
#                <small>
#                 Chile
#                </small>
#               </p>
#               <p>
#                <small>
#                 <strong>
#                  2015 - 2015
#                 </strong>
#                </small>
#               </p>
#              </div>
#             </li>
#             <li class="muted" style="margin-bottom:20px;">
#              <h5>
#               <i class="ace-icon fa fa-angle-right bigger-110">
#               </i>
#               <strong>
#                Docente del curso Metodología de la investigación cualitativa
#               </strong>
#               <small>
#               </small>
#              </h5>
#              <div style="margin-left:10px;">
#               <p>
#                <span class="text-warning capitalize">
#                 Universidad Andrés Bello. Carrera de Sociología.
#                </span>
#               </p>
#               <p>
#                <small>
#                 Chile
#                </small>
#               </p>
#               <p>
#                <small>
#                 <strong>
#                  2015 - 2015
#                 </strong>
#                </small>
#               </p>
#              </div>
#             </li>
#             <li class="muted" style="margin-bottom:20px;">
#              <h5>
#               <i class="ace-icon fa fa-angle-right bigger-110">
#               </i>
#               <strong>
#                Docente del curso Políticas Públicas
#               </strong>
#               <small>
#               </small>
#              </h5>
#              <div style="margin-left:10px;">
#               <p>
#                <span class="text-warning capitalize">
#                 Universidad Andrés Bello. Carrera de Sociología.
#                </span>
#               </p>
#               <p>
#                <small>
#                 Chile
#                </small>
#               </p>
#               <p>
#                <small>
#                 <strong>
#                  2015 - 2015
#                 </strong>
#                </small>
#               </p>
#              </div>
#             </li>
#             <li class="muted" style="margin-bottom:20px;">
#              <h5>
#               <i class="ace-icon fa fa-angle-right bigger-110">
#               </i>
#               <strong>
#                Docente del curso Socioantropología
#               </strong>
#               <small>
#               </small>
#              </h5>
#              <div style="margin-left:10px;">
#               <p>
#                <span class="text-warning capitalize">
#                 Universidad Andrés Bello. Departamento de Enfermería.
#                </span>
#               </p>
#               <p>
#                <small>
#                 Chile
#                </small>
#               </p>
#               <p>
#                <small>
#                 <strong>
#                  2015 - 2015
#                 </strong>
#                </small>
#               </p>
#              </div>
#             </li>
#             <li class="muted" style="margin-bottom:20px;">
#              <h5>
#               <i class="ace-icon fa fa-angle-right bigger-110">
#               </i>
#               <strong>
#                Docente del curso Sociología de la educación
#               </strong>
#               <small>
#               </small>
#              </h5>
#              <div style="margin-left:10px;">
#               <p>
#                <span class="text-warning capitalize">
#                 Universidad de Playa Ancha. Departamento de Sociología.
#                </span>
#               </p>
#               <p>
#                <small>
#                 Chile
#                </small>
#               </p>
#               <p>
#                <small>
#                 <strong>
#                  2010 - 2010
#                 </strong>
#                </small>
#               </p>
#              </div>
#             </li>
#             <li class="muted" style="margin-bottom:20px;">
#              <h5>
#               <i class="ace-icon fa fa-angle-right bigger-110">
#               </i>
#               <strong>
#                Docente del curso Métodos de investigación científica.
#               </strong>
#               <small>
#               </small>
#              </h5>
#              <div style="margin-left:10px;">
#               <p>
#                <span class="text-warning capitalize">
#                 Universidad de Playa Ancha. Departamento de Bibliotecología.
#                </span>
#               </p>
#               <p>
#                <small>
#                 Chile
#                </small>
#               </p>
#               <p>
#                <small>
#                 <strong>
#                  2010 - 2010
#                 </strong>
#                </small>
#               </p>
#              </div>
#             </li>
#             <li class="muted" style="margin-bottom:20px;">
#              <h5>
#               <i class="ace-icon fa fa-angle-right bigger-110">
#               </i>
#               <strong>
#                Docente informante de tesis
#               </strong>
#               <small>
#               </small>
#              </h5>
#              <div style="margin-left:10px;">
#               <p>
#                <span class="text-warning capitalize">
#                 Universidad de Playa Ancha. Departamento de Sociología.
#                </span>
#               </p>
#               <p>
#                <small>
#                 Chile
#                </small>
#               </p>
#               <p>
#                <small>
#                 <strong>
#                  2015 - A la fecha
#                 </strong>
#                </small>
#               </p>
#              </div>
#             </li>
#             <li class="muted" style="margin-bottom:20px;">
#              <h5>
#               <i class="ace-icon fa fa-angle-right bigger-110">
#               </i>
#               <strong>
#                Planificación del curso: Salud pública y políticas públicas, del Máster en Salud Primaria.
#               </strong>
#               <small>
#               </small>
#              </h5>
#              <div style="margin-left:10px;">
#               <p>
#                <span class="text-warning capitalize">
#                 Universidad Andrés Bello.
#                </span>
#               </p>
#               <p>
#                <small>
#                 Chile
#                </small>
#               </p>
#               <p>
#                <small>
#                 <strong>
#                  2010 - 2011
#                 </strong>
#                </small>
#               </p>
#              </div>
#             </li>
#             <li class="muted" style="margin-bottom:20px;">
#              <h5>
#               <i class="ace-icon fa fa-angle-right bigger-110">
#               </i>
#               <strong>
#                Coordinadora de Prácticas Profesionales.
#               </strong>
#               <small>
#               </small>
#              </h5>
#              <div style="margin-left:10px;">
#               <p>
#                <span class="text-warning capitalize">
#                 Universidad de Playa Ancha. Departamento de Sociología.
#                </span>
#               </p>
#               <p>
#                <small>
#                 Chile
#                </small>
#               </p>
#               <p>
#                <small>
#                 <strong>
#                  2010 - 2010
#                 </strong>
#                </small>
#               </p>
#              </div>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <div class="tab-pane fade" id="messages">
#           <div style="clear:both;">
#           </div>
#           <div class="row-fluid">
#           </div>
#          </div>
#          <div class="tab-pane fade" id="colab">
#           <div class="row">
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- /.main-content -->
#    <!-- /.footer -->
#    <div class="footer">
#    </div>
#    <a class="btn-scroll-up btn btn-sm btn-inverse" href="#" id="btn-scroll-up">
#     <i class="ace-icon fa fa-angle-double-up icon-only bigger-110">
#     </i>
#    </a>
#   </div>
#   <!-- /.main-container -->
#   <!-- basic scripts -->
#   <!--[if !IE]> -->
#   <script src="/javascripts/external/jquery.js">
#   </script>
#   <!-- <![endif]-->
#   <!--[if IE]>
# <script src="/javascripts/external/jquery1x.js"></script>
# <![endif]-->
#   <script type="text/javascript">
#    if('ontouchstart' in document.documentElement) document.write("<script src='/javascripts/external/jquery.mobile.custom.js'>"+"<"+"/script>");
#   </script>
#   <script src="/javascripts/external/bootstrap.js">
#   </script>
#   <!-- page specific plugin scripts -->
#   <script src="/javascripts/external/jquery.nestable.js">
#   </script>
#   <!-- ace scripts -->
#   <script src="/javascripts/external/ace/elements.scroller.js">
#   </script>
#   <script src="/javascripts/external/ace/elements.spinner.js">
#   </script>
#   <script src="/javascripts/external/ace/elements.aside.js">
#   </script>
#   <script src="/javascripts/external/ace/ace.js">
#   </script>
#   <script src="/javascripts/external/ace/ace.ajax-content.js">
#   </script>
#   <script src="/javascripts/external/ace/ace.sidebar.js">
#   </script>
#   <script src="/javascripts/external/ace/ace.sidebar-scroll-1.js">
#   </script>
#   <script src="/javascripts/external/ace/ace.submenu-hover.js">
#   </script>
#   <script src="/javascripts/external/ace/ace.widget-box.js">
#   </script>
#   <script src="/javascripts/external/ace/ace.settings-rtl.js">
#   </script>
#   <script src="/javascripts/external/ace/ace.settings-skin.js">
#   </script>
#   <script src="/javascripts/external/ace/ace.widget-on-reload.js">
#   </script>
#   <script src="/javascripts/external/ace/ace.searchbox-autocomplete.js">
#   </script>
#   <script src="/javascripts/pia/jquery.dataTables.min.js?1635187222" type="text/javascript">
#   </script>
#   <script src="/javascripts/pia/jquery.dataTables.bootstrap.js?1635187222" type="text/javascript">
#   </script>
#   <!-- inline scripts related to this page -->
#   <script type="text/javascript">
#    jQuery(function($){
#
# 				$('.dd').nestable();
#
# 				$('.dd-handle a').on('mousedown', function(e){
# 					e.stopPropagation();
# 				});
#
# 				$('[data-rel="tooltip"]').tooltip();
# 				$('.data-list').DataTable({
#   dom: 'ft',
#   paging:false,
#   language:{
#     search: 'Buscar:',
#     zeroRecords: 'Sin resultados para su búsqueda.'
#   },
#   aaSorting: []
#   //autowidth: false,
#   //paging: false,
#   //aaSorting: [[ 2, 'desc' ], [3,'asc']],
#   //deferRender: true,
#   //createdRow: function(row, data, dataIndex){
#   //  $(row).attr('id', "pia_reports_award_"+data[4]);
#   //},
# });
#
#
# 			});
#   </script>
#  </body>
# </html>

# %%
ANID_soup.find('div', attrs={'class': 'col-sm-6'})
# Out:
# <div class="col-sm-6" style="line-height:7px;margin-top:-15px;">
# <h3>
# <strong>Elizabeth Patricia Zenteno Torres</strong>
# </h3>
# <p style="line-height:12px;">
# <strong>Profesor Asistente</strong>
# </p>
# <p style="line-height:12px;">UNIVERSIDAD DE PLAYA ANCHA DE CIENCIAS DE LA EDUCACION</p>
# <p>
# <small></small>
# </p>
# </div>

# %%
a = ANID_soup.find('div', attrs={'class': 'col-sm-6'}).get_text()
# Out:
# '\n\nElizabeth Patricia Zenteno Torres\n\n\nProfesor Asistente\n\nUNIVERSIDAD DE PLAYA ANCHA DE CIENCIAS DE LA EDUCACION\n\n\n\n'

# %%
ANID_soup.find('div', attrs={'class': 'col-sm-6'}).find_all('p')
# Out:
# [<p style="line-height:12px;">
#  <strong>Profesor Asistente</strong>
#  </p>,
#  <p style="line-height:12px;">UNIVERSIDAD DE PLAYA ANCHA DE CIENCIAS DE LA EDUCACION</p>,
#  <p>
#  <small></small>
#  </p>]

# %%
ANID_soup.find('div', attrs={'class': 'tabbable'})
# Out:
# <div class="tabbable">
# <ul class="nav nav-tabs" id="myTab">
# <li class="active">
# <a aria-expanded="true" data-toggle="tab" href="#home">
# <i class="default ace-icon fa fa-user bigger-120"></i>
# Currículo
# </a>
# </li>
# <li>
# <a aria-expanded="false" data-toggle="tab" href="#messages">
# <i class="default ace-icon fa fa-file-text bigger-120"></i>
# Producción (0)
# </a>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" data-toggle="tab" href="#colab">
# <i class="default ace-icon fa fa-users bigger-120"></i>
# Colaboraciones (0)
# </a>
# </li>
# </ul>
# <div class="tab-content">
# <div class="tab-pane fade active in" id="home">
# <div class="widget-header widget-header-small" style="background:none;">
# <h4 class="widget-title blue smaller">
# <i class="ace-icon fa fa-bookmark orange"></i>
# Líneas de Investigación
# </h4>
# </div>
# <br/>
# <p>Sociología urbana; Pobreza y segregación urbana; Metodología cualitativa</p>
# <div class="widget-header widget-header-small" style="background:none;margin-top:40px;">
# <h4 class="widget-title blue smaller">
# <i class="ace-icon fa fa-graduation-cap orange"></i>
# Educación
# </h4>
# </div>
# <div>
# <ul class="list-unstyled">
# <li class="muted">
# <h5><i class="ace-icon fa fa-angle-right bigger-110"></i> <strong>Licenciatura en Sociología</strong>,
# <span class="text-warning">UNIVERSIDAD DE PLAYA ANCHA DE CIENCIAS DE LA EDUCACION</span>.
# <small>Chile, 2008</small>
# </h5>
# </li>
# <li class="muted">
# <h5><i class="ace-icon fa fa-angle-right bigger-110"></i> <strong>MASTER CONJUNTO INTERNACIONAL EN POLÍTICAS PÚBLICAS Y DESARROLLO TERRITORIAL: GOBERNABILIDAD Y PROCESOS DE INTEGRACIÓN</strong>,
# <span class="text-warning">UNIVERSITA DEGLI STUDI DI PALERMO</span>.
# <small>Italia, 2010</small>
# </h5>
# </li>
# <li class="muted">
# <h5><i class="ace-icon fa fa-angle-right bigger-110"></i> <strong>DOCTORADO EN TEORÍA E INVESTIGACIÓN SOCIAL</strong>,
# <span class="text-warning">UNIVERSITA DEGLI STUDI DI ROMA LA SAPIENZA</span>.
# <small>Italia, 2015</small>
# </h5>
# </li>
# <li class="muted">
# <h5><i class="ace-icon fa fa-angle-right bigger-110"></i> <strong>Sociólogo</strong>,
# <span class="text-warning">UNIVERSIDAD DE PLAYA ANCHA DE CIENCIAS DE LA EDUCACION</span>.
# <small>Chile, 2008</small>
# </h5>
# </li>
# </ul>
# </div>
# <div class="widget-header widget-header-small" style="background:none;margin-top:40px;">
# <h4 class="widget-title blue smaller">
# <i class="ace-icon fa fa-institution orange"></i>
# Experiencia Académica
# </h4>
# </div>
# <div>
# <ul class="list-unstyled" style="line-height:10px;">
# <li class="muted" style="margin-bottom:20px;">
# <h5><i class="ace-icon fa fa-angle-right bigger-110"></i>
# <strong>Profesor Asistente</strong>
# <small>Part Time</small>
# </h5>
# <div style="margin-left:10px;">
# <p>
# <span class="text-warning capitalize">UNIVERSIDAD DE PLAYA ANCHA DE CIENCIAS DE LA EDUCACION</span>
# </p>
# <p>Ciencias Sociales</p>
# <p>
# <small>Valparaíso, Chile</small>
# </p>
# <p>
# <small>
# <strong>2015 - A la fecha</strong>
# </small>
# </p>
# </div>
# </li>
# </ul>
# </div>
# <div class="widget-header widget-header-small" style="background:none;margin-top:40px;">
# <h4 class="widget-title blue smaller">
# <i class="ace-icon fa fa-suitcase orange"></i>
# Experiencia Profesional
# </h4>
# </div>
# <div>
# <ul class="list-unstyled" style="line-height:10px;">
# <li class="muted" style="margin-bottom:20px;">
# <h5><i class="ace-icon fa fa-angle-right bigger-110"></i>
# <strong>Docente del curso Etnografía de la alteridad</strong>
# <small></small>
# </h5>
# <div style="margin-left:10px;">
# <p>
# <span class="text-warning capitalize">Universidad de Playa Ancha. Departamento de Sociología.</span>
# </p>
# <p>
# <small>Chile</small>
# </p>
# <p>
# <small>
# <strong>2016 - A la fecha</strong>
# </small>
# </p>
# </div>
# </li>
# <li class="muted" style="margin-bottom:20px;">
# <h5><i class="ace-icon fa fa-angle-right bigger-110"></i>
# <strong>Docente del curso Metodología de la investigación I</strong>
# <small></small>
# </h5>
# <div style="margin-left:10px;">
# <p>
# <span class="text-warning capitalize">Universidad de Playa Ancha. Departamento de Sociología.</span>
# </p>
# <p>
# <small>Chile</small>
# </p>
# <p>
# <small>
# <strong>2015 - A la fecha</strong>
# </small>
# </p>
# </div>
# </li>
# <li class="muted" style="margin-bottom:20px;">
# <h5><i class="ace-icon fa fa-angle-right bigger-110"></i>
# <strong>Docente del curso Metodología de la Investigación Cualitativa I</strong>
# <small></small>
# </h5>
# <div style="margin-left:10px;">
# <p>
# <span class="text-warning capitalize">Universidad de Playa Ancha. Departamento de Sociología.</span>
# </p>
# <p>
# <small>Chile</small>
# </p>
# <p>
# <small>
# <strong>2015 - A la fecha</strong>
# </small>
# </p>
# </div>
# </li>
# <li class="muted" style="margin-bottom:20px;">
# <h5><i class="ace-icon fa fa-angle-right bigger-110"></i>
# <strong>Docente del curso Sociología General</strong>
# <small></small>
# </h5>
# <div style="margin-left:10px;">
# <p>
# <span class="text-warning capitalize">Universidad de Playa Ancha. Carrera: Terapia Ocupacional</span>
# </p>
# <p>
# <small>Chile</small>
# </p>
# <p>
# <small>
# <strong>2016 - A la fecha</strong>
# </small>
# </p>
# </div>
# </li>
# <li class="muted" style="margin-bottom:20px;">
# <h5><i class="ace-icon fa fa-angle-right bigger-110"></i>
# <strong>Docente del curso Población y Desarrollo Sustentable</strong>
# <small></small>
# </h5>
# <div style="margin-left:10px;">
# <p>
# <span class="text-warning capitalize">Universidad de Playa Ancha. Departamento de Sociología.</span>
# </p>
# <p>
# <small>Chile</small>
# </p>
# <p>
# <small>
# <strong>2015 - 2015</strong>
# </small>
# </p>
# </div>
# </li>
# <li class="muted" style="margin-bottom:20px;">
# <h5><i class="ace-icon fa fa-angle-right bigger-110"></i>
# <strong>Docente del curso Metodología de la investigación cualitativa</strong>
# <small></small>
# </h5>
# <div style="margin-left:10px;">
# <p>
# <span class="text-warning capitalize">Universidad Andrés Bello. Carrera de Sociología.</span>
# </p>
# <p>
# <small>Chile</small>
# </p>
# <p>
# <small>
# <strong>2015 - 2015</strong>
# </small>
# </p>
# </div>
# </li>
# <li class="muted" style="margin-bottom:20px;">
# <h5><i class="ace-icon fa fa-angle-right bigger-110"></i>
# <strong>Docente del curso Políticas Públicas</strong>
# <small></small>
# </h5>
# <div style="margin-left:10px;">
# <p>
# <span class="text-warning capitalize">Universidad Andrés Bello. Carrera de Sociología.</span>
# </p>
# <p>
# <small>Chile</small>
# </p>
# <p>
# <small>
# <strong>2015 - 2015</strong>
# </small>
# </p>
# </div>
# </li>
# <li class="muted" style="margin-bottom:20px;">
# <h5><i class="ace-icon fa fa-angle-right bigger-110"></i>
# <strong>Docente del curso Socioantropología</strong>
# <small></small>
# </h5>
# <div style="margin-left:10px;">
# <p>
# <span class="text-warning capitalize">Universidad Andrés Bello. Departamento de Enfermería.</span>
# </p>
# <p>
# <small>Chile</small>
# </p>
# <p>
# <small>
# <strong>2015 - 2015</strong>
# </small>
# </p>
# </div>
# </li>
# <li class="muted" style="margin-bottom:20px;">
# <h5><i class="ace-icon fa fa-angle-right bigger-110"></i>
# <strong>Docente del curso Sociología de la educación</strong>
# <small></small>
# </h5>
# <div style="margin-left:10px;">
# <p>
# <span class="text-warning capitalize">Universidad de Playa Ancha. Departamento de Sociología.</span>
# </p>
# <p>
# <small>Chile</small>
# </p>
# <p>
# <small>
# <strong>2010 - 2010</strong>
# </small>
# </p>
# </div>
# </li>
# <li class="muted" style="margin-bottom:20px;">
# <h5><i class="ace-icon fa fa-angle-right bigger-110"></i>
# <strong>Docente del curso Métodos de investigación científica. </strong>
# <small></small>
# </h5>
# <div style="margin-left:10px;">
# <p>
# <span class="text-warning capitalize">Universidad de Playa Ancha. Departamento de Bibliotecología.</span>
# </p>
# <p>
# <small>Chile</small>
# </p>
# <p>
# <small>
# <strong>2010 - 2010</strong>
# </small>
# </p>
# </div>
# </li>
# <li class="muted" style="margin-bottom:20px;">
# <h5><i class="ace-icon fa fa-angle-right bigger-110"></i>
# <strong>Docente informante de tesis</strong>
# <small></small>
# </h5>
# <div style="margin-left:10px;">
# <p>
# <span class="text-warning capitalize">Universidad de Playa Ancha. Departamento de Sociología.</span>
# </p>
# <p>
# <small>Chile</small>
# </p>
# <p>
# <small>
# <strong>2015 - A la fecha</strong>
# </small>
# </p>
# </div>
# </li>
# <li class="muted" style="margin-bottom:20px;">
# <h5><i class="ace-icon fa fa-angle-right bigger-110"></i>
# <strong>Planificación del curso: Salud pública y políticas públicas, del Máster en Salud Primaria.</strong>
# <small></small>
# </h5>
# <div style="margin-left:10px;">
# <p>
# <span class="text-warning capitalize">Universidad Andrés Bello.</span>
# </p>
# <p>
# <small>Chile</small>
# </p>
# <p>
# <small>
# <strong>2010 - 2011</strong>
# </small>
# </p>
# </div>
# </li>
# <li class="muted" style="margin-bottom:20px;">
# <h5><i class="ace-icon fa fa-angle-right bigger-110"></i>
# <strong>Coordinadora de Prácticas Profesionales.</strong>
# <small></small>
# </h5>
# <div style="margin-left:10px;">
# <p>
# <span class="text-warning capitalize">Universidad de Playa Ancha. Departamento de Sociología.</span>
# </p>
# <p>
# <small>Chile</small>
# </p>
# <p>
# <small>
# <strong>2010 - 2010</strong>
# </small>
# </p>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="tab-pane fade" id="messages">
# <div style="clear:both;"> </div>
# <div class="row-fluid">
# </div>
# </div>
# <div class="tab-pane fade" id="colab">
# <div class="row">
# </div>
# </div>
# </div>
# </div>

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup


def main():
    min = 10000
    max = 10030
    url = "https://investigadores.anid.cl/es/public_search/researcher?id="

    df = pd.DataFrame(columns=['Name', 'Position', 'University', 'Place', 'Code'])

    for code in range(min, max + 1):
        url_code = url + str(code)
        anid = requests.get(url_code)

        if len(anid.text) != 728:

            if anid.status_code == 200:
                anid_soup = BeautifulSoup(anid.text, 'lxml')
                a = anid_soup.find('div', attrs={'class': 'col-sm-6'}).get_text()
                a = a.split("\n")
                b = []

                for i in range(len(a)):
                    if len(a[i]) > 0:
                        # print(a[i])
                        b.append(a[i])

                if len(b) == 3:
                    df = df.append({'Name': b[0], 'University': b[1], 'Place': b[2], 'Code': code}, ignore_index=True)
                elif len(b) == 4:
                    df = df.append({'Name': b[0], 'Position': b[1], 'University': b[2], 'Place': b[3], 'Code': code},
                                   ignore_index=True)
                else:
                    pass
                # print(b[0])

                df.to_csv('DATA/investigadores.anid.csv', index=False, encoding='utf-8')

    print(df)


if __name__ == "__main__":
    main()
# Out:
#                                      Name  \
# 0         Lunelia Sonia Betancour Sanchez
# 1           Jaime Arturo Otazo Hermosilla
# 2     Patricio Alejandro Rojas Montecinos
# 3           Patricio Rodrigo Orio Alvarez
# 4                    María Pertusa Pastor
# 5               Reinaldo Salazar Espinoza
# 6         Elke Elisabeth Schlack Fuhrmann
# 7              Nancy Rocío Hidalgo Cepeda
# 8   Apolinaria del Rosario García Cancino
# 9           José Manuel Del Valle Lladser
# 10           Gonzalo Alexis Núñez Montoya
# 11                           Pedro Reszka
# 12         Andres Hernan Fuentes Castillo
# 13              Macarena Gerding González
# 14            Juan Carlos Ferrada Borquez
# 15            Paulina Andrea Ruiz Cabello
# 16        Albert Leandro Herrera Zeppelin
# 17    José Alberto De La Fuente Arancibia
# 18                   Laura Reagan Stephan
# 19             Gonzalo Bustamante Kuschel
# 20           Cecilia Andrea Rivera Castro
# 21                     Rodrigo Villaseñor
# 22               Raúl Pedro Elgueta Rosas
# 23                  Barbara Crettier Bize
# 24    Guillermo Rodrigo Petzold Maldonado
# 25     Raúl Jesús Enrique Pizarro Sánchez
# 26                       Pablo Andres Rey
# 27   Javier Alejandro Guerrero Bustamante
# 28             Ivan Esteban Alfaro Cortez
# 29       Jaime Alejandro Catalán González
#
#                                              Position  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                 Assistant Professor
# 3                                    Profesor Titular
# 4                                  Profesor Asistente
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                        Investigador
# 9                                                 NaN
# 10                                                NaN
# 11                                Associate Professor
# 12                                  Professor Adjunto
# 13                                  Profesor Asociado
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                Associate Professor
# 20                           académico e investigador
# 21                                                NaN
# 22                                           Asociado
# 23                                                NaN
# 24                                Associate Professor
# 25                                                NaN
# 26                                          Académico
# 27                                    Gerente General
# 28  Associate Professor, Director of Innovation an...
# 29                                                NaN
#
#                                            University  \
# 0                          UNIVERSIDAD DE LA FRONTERA
# 1                          UNIVERSIDAD DE LA FRONTERA
# 2                    UNIVERSIDAD DE SANTIAGO DE CHILE
# 3                           UNIVERSIDAD DE VALPARAÍSO
# 4   UNIVERSIDAD DE SANTIAGO DE CHILE. FACULTAD QUÍ...
# 5                          UNIVERSIDAD DE PLAYA ANCHA
# 6                            UNIVERSIDAD ANDRES BELLO
# 7            PONTIFICIA UNIVERSIDAD CATÓLICA DE CHILE
# 8                           UNIVERSIDAD DE CONCEPCIÓN
# 9            PONTIFICIA UNIVERSIDAD CATÓLICA DE CHILE
# 10           PONTIFICIA UNIVERSIDAD CATÓLICA DE CHILE
# 11                          Universidad Adolfo Ibáñez
# 12            UNIVERSIDAD TÉNICA FEDERICO SANTA MARÍA
# 13   UNIVERSIDAD DE CONCEPCIÓN, FACULTAD DE AGRONOMÍA
# 14                          UNIVERSIDAD DE VALPARAÍSO
# 15  CENTRO DE INVESTIGACIÓN AVANZADA EN EDUCACIÓN,...
# 16                    PONTIFICIA UNIVERSIDAD CATÓLICA
# 17               UNIVERSIDAD CATÓLICA SIKVA HENRÍQUEZ
# 18                          UNIVERSIDAD ADOLFO IBÁÑEZ
# 19                          Universidad Adolfo Ibáñez
# 20                         UNIVERSITY OF  PLAYA ANCHA
# 21                         UNIVERSIDAD DE PLAYA ANCHA
# 22                                         IDEA-USACH
# 23            UNIVERSIDAD CATÓLICA DEL NORTE (CREDHU)
# 24                            UNIVERSIDAD DEL BÍO-BÍO
# 25                         UNIVERSIDAD DE PLAYA ANCHA
# 26              Universidad Tecnológica Metropolitana
# 27                                 Praxis Biotech SpA
# 28                         Universidad del Desarrollo
# 29              UNIVERSIDAD DE CHILE HOSPITAL CLINICO
#
#                        Place   Code
# 0              Temuco, Chile  10000
# 1              Temuco, Chile  10001
# 2            Santiago, Chile  10002
# 3          Valparaíso, Chile  10003
# 4            Santiago, Chile  10004
# 5          Valparaíso, Chile  10005
# 6            Santiago, Chile  10006
# 7            Santiago, Chile  10007
# 8          Concepción, Chile  10009
# 9            Santiafo, Chile  10010
# 10           Santiago, Chile  10011
# 11           Santiago, Chile  10012
# 12         Valparaíso, Chile  10013
# 13            Chillán, Chile  10014
# 14         Valparaíso, Chile  10015
# 15           Santiago, Chile  10016
# 16           Santiago, Chile  10017
# 17           Santiago, Chile  10018
# 18           Santiago, Chile  10019
# 19           Santiago, Chile  10020
# 20         VALPARAISO, Chile  10021
# 21         Valparaíso, Chile  10022
# 22  Santiago de Chile, Chile  10023
# 23           Coquimbo, Chile  10024
# 24            Chillan, Chile  10025
# 25         Valparaíso, Chile  10026
# 26           Santiago, Chile  10027
# 27           Santiago, Chile  10028
# 28           Santiago, Chile  10029
# 29           Santiago, Chile  10030

# %%
import pandas as pd

data = pd.read_csv('DATA/investigadores.anid.csv')

# %%
data
# Out:
#                                     Name                    Position  \
# 0        Lunelia Sonia Betancour Sanchez                         NaN
# 1          Jaime Arturo Otazo Hermosilla                         NaN
# 2    Patricio Alejandro Rojas Montecinos         Assistant Professor
# 3          Patricio Rodrigo Orio Alvarez            Profesor Titular
# 4                   María Pertusa Pastor          Profesor Asistente
# ..                                   ...                         ...
# 238          Maria Teresa Planella Ortiz                         NaN
# 239       Luciana Daniela Quiroz Ledesma                         NaN
# 240      Carolina Andrea Belmar Pantelis         Profesora Asistente
# 241                         Andrea Biere                         NaN
# 242    RICARDO ENRIQUE TRUFFELLO ROBLEDO  Profesor Asistente Adjunto
#
#                                             University              Place  \
# 0                           UNIVERSIDAD DE LA FRONTERA      Temuco, Chile
# 1                           UNIVERSIDAD DE LA FRONTERA      Temuco, Chile
# 2                     UNIVERSIDAD DE SANTIAGO DE CHILE    Santiago, Chile
# 3                            UNIVERSIDAD DE VALPARAÍSO  Valparaíso, Chile
# 4    UNIVERSIDAD DE SANTIAGO DE CHILE. FACULTAD QUÍ...    Santiago, Chile
# ..                                                 ...                ...
# 238                         MUSEO REGIONAL DE RANCAGUA    Rancagua, Chile
# 239                                         PARTICULAR    Santiago, Chile
# 240                               Universidad de Chile    Santiago, Chile
# 241              HOSPITAL CLINICO UNIVERSIDAD DE CHILE    santiago, Chile
# 242           Pontificia Universidad Católica de Chile    Santiago, Chile
#
#       Code
# 0    10000
# 1    10001
# 2    10002
# 3    10003
# 4    10004
# ..     ...
# 238  10260
# 239  10261
# 240  10262
# 241  10263
# 242  10264
#
# [243 rows x 5 columns]
